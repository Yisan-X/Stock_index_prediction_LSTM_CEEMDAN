# %%
import numpy as np 
import pandas as pd 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style("whitegrid")
from datetime import datetime
import warnings

warnings.filterwarnings("ignore")

# %%
SS_index = pd.read_csv(r"C:\Users\86187\Desktop\CUHKSZ\FTE4560\CODES\SequentialNeuralNet\IDX_Idxtrd_1.csv")
SS_index = SS_index.drop("Indexcd", axis=1)
SS_index.columns = ["Date", "Open", "High", "Low", "Close", "Amount", "Volume"]
SS_index = SS_index.set_index("Date")
SS_index.index = pd.to_datetime(SS_index.index)
SS_index
# Out:
#                  Open       High        Low      Close      Amount  \
# Date
# 2016-05-03  10144.153  10441.920  10105.799  10441.920   968484.14
# 2016-05-04  10401.675  10498.315  10389.771  10422.802   932165.26
# 2016-05-05  10403.550  10480.221  10372.216  10474.013   805724.47
# 2016-05-06  10473.303  10501.435  10100.535  10100.535  1193074.30
# 2016-05-09  10018.507  10018.507   9747.872   9790.477   955844.31
# ...               ...        ...        ...        ...         ...
# 2021-04-26  14419.851  14529.428  14212.223  14224.448  1586622.34
# 2021-04-27  14211.585  14266.599  14106.830  14264.084  1285087.05
# 2021-04-28  14238.564  14398.961  14190.638  14398.381  1250826.66
# 2021-04-29  14416.850  14516.221  14330.089  14464.082  1225232.00
# 2021-04-30  14437.169  14522.456  14343.061  14438.567  1342798.22
#
#                  Volume
# Date
# 2016-05-03  15332072.26
# 2016-05-04  14704422.16
# 2016-05-05  12856956.78
# 2016-05-06  18119218.42
# 2016-05-09  13539675.55
# ...                 ...
# 2021-04-26  30754184.88
# 2021-04-27  23965411.24
# 2021-04-28  24533213.76
# 2021-04-29  24959762.43
# 2021-04-30  26833357.88
#
# [1217 rows x 6 columns]

# %%
SZ_index = pd.read_csv(r"C:\Users\86187\Desktop\CUHKSZ\FTE4560\CODES\SequentialNeuralNet\IDX_Idxtrd.csv")
SZ_index = SZ_index.drop("Indexcd", axis=1)
SZ_index.columns = ["Date", "Open", "High", "Low", "Close", "Amount", "Volume"]
SZ_index = SZ_index.set_index("Date")
SZ_index.index = pd.to_datetime(SZ_index.index)
SZ_index
# Out:
#                 Open      High       Low     Close      Amount       Volume
# Date
# 2016-04-21  2954.370  2990.673  2943.464  2952.891  1894068.49  20647712.69
# 2016-04-22  2933.035  2960.209  2926.776  2959.240  1372116.68  14880043.08
# 2016-04-25  2949.973  2954.092  2917.020  2946.670  1258562.43  14063875.63
# 2016-04-26  2944.716  2965.429  2933.971  2964.700  1177116.04  13429245.87
# 2016-04-27  2967.190  2976.022  2949.432  2953.671  1308676.40  15028630.15
# ...              ...       ...       ...       ...         ...          ...
# 2021-04-14  3397.021  3420.028  3392.975  3416.721  2332423.27  26901007.06
# 2021-04-15  3409.614  3409.614  3373.094  3398.988  2340050.54  27256919.68
# 2021-04-16  3407.188  3432.629  3394.134  3426.618  2585796.72  29595109.47
# 2021-04-19  3427.548  3479.010  3414.356  3477.549  3027358.19  36847246.75
# 2021-04-20  3467.148  3494.298  3463.464  3472.943  2853000.82  35898276.82
#
# [1216 rows x 6 columns]

# %%
sns.histplot(SS_index["Close"], kde=True)
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Count'>

# %%
sns.histplot(SZ_index["Close"], kde=True)
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

data_ceemd_ = SZ_index[["Close"]]
# scl = MinMaxScaler()
# data_ica_ = scl.fit_transform(data_)
# data_ceemd_ = data_ceemd_.applymap(lambda x: np.log(x))
# data_ceemd_ = data_ceemd_.diff(axis=0)
data_ceemd_.dropna(inplace=True)
scl = MinMaxScaler()
data_ceemd_ = scl.fit_transform(data_ceemd_)
data_ceemd = pd.DataFrame(data=data_ceemd_, index=SZ_index.index)
data_ceemd.shape
# Out:
# (1216, 1)

# %%
from PyEMD import CEEMDAN

ceemdan = CEEMDAN()
cIMFs = ceemdan(np.ravel(np.array(data_ceemd)))
cIMFs = cIMFs.T

# %%
# fig,ax = plt.subplots(1,1,figsize=(18,5))
# ax.plot(np.array(data_ceemd))
# ax.set_title("Source Signals", fontsize=30)
# ax.set_xlabel("Time(day)")
# plt.savefig(save_path+r"\CEEMDAN_source.png")

fig,ax = plt.subplots(3,3,figsize=(15,9))
# ax[0].set_title("Intrinsic Mode Functions", fontsize=30)
error = np.ravel(np.array(data_ceemd))
for i in range(2):
    for j in range(3):
        ax[i,j].plot(cIMFs[:,i*3+j], label="IMF%d"%(i*3+j+1))
        ax[i,j].legend(loc="upper left")
        error = error - cIMFs[:,i*3+j]

for j in range(2):
    ax[2,j].plot(cIMFs[:,6+j], label="IMF%d"%(6+j+1))
    ax[2,j].legend(loc="upper left")
    error = error - cIMFs[:,6+j]

ax[2,2].plot(error, label="error")
ax[2,2].legend(loc="upper left")
# for i in range(cIMFs.shape[1]):
#     ax[i].plot(cIMFs[:,i], label="IMF%d"%(i+1))
#     ax[i].legend(loc="upper left", fontsize=8)
#     error = error - cIMFs[:,i]
# ax[i+1].plot(error, label="ERROR")
# ax[i+1].legend(loc="upper left", fontsize=8)
# ax[i+1].set_xlabel("Time(day)")
# plt.savefig(save_path+r"\CEEMDAN_IMF.png")

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

data_ceemd_ = SS_index[["Close"]]
# scl = MinMaxScaler()
# data_ica_ = scl.fit_transform(data_)
# data_ceemd_ = data_ceemd_.applymap(lambda x: np.log(x))
# data_ceemd_ = data_ceemd_.diff(axis=0)
data_ceemd_.dropna(inplace=True)
scl = MinMaxScaler()
data_ceemd_ = scl.fit_transform(data_ceemd_)
data_ceemd = pd.DataFrame(data=data_ceemd_, index=SS_index.index)
data_ceemd.shape
# Out:
# (1217, 1)

# %%
from PyEMD import CEEMDAN

ceemdan = CEEMDAN()
cIMFs = ceemdan(np.ravel(np.array(data_ceemd)))
cIMFs = cIMFs.T

# %%
# fig,ax = plt.subplots(1,1,figsize=(18,5))
# ax.plot(np.array(data_ceemd))
# ax.set_title("Source Signals", fontsize=30)
# ax.set_xlabel("Time(day)")
# plt.savefig(save_path+r"\CEEMDAN_source.png")

fig,ax = plt.subplots(3,3,figsize=(15,9))
# ax[0].set_title("Intrinsic Mode Functions", fontsize=30)
error = np.ravel(np.array(data_ceemd))
for i in range(2):
    for j in range(3):
        ax[i,j].plot(cIMFs[:,i*3+j], label="IMF%d"%(i*3+j+1))
        ax[i,j].legend(loc="upper left")
        error = error - cIMFs[:,i*3+j]

for j in range(2):
    ax[2,j].plot(cIMFs[:,6+j], label="IMF%d"%(6+j+1))
    ax[2,j].legend(loc="upper left")
    error = error - cIMFs[:,6+j]

ax[2,2].plot(error, label="error")
ax[2,2].legend(loc="upper left")
# for i in range(cIMFs.shape[1]):
#     ax[i].plot(cIMFs[:,i], label="IMF%d"%(i+1))
#     ax[i].legend(loc="upper left", fontsize=8)
#     error = error - cIMFs[:,i]
# ax[i+1].plot(error, label="ERROR")
# ax[i+1].legend(loc="upper left", fontsize=8)
# ax[i+1].set_xlabel("Time(day)")
# plt.savefig(save_path+r"\CEEMDAN_IMF.png")

# %%
# from data_generator import *
import time
from rnn import *
from optimizers import *
from activator import *
from utils import *
from Structure import *
from fclayer import *
from LSTM import *
from ICA import *

# %%
BATCH_SIZE = 10
NUM_NEURONS_FirstLayer = 20
NUM_NEURONS_SecondLayer = 60
optmParamsLSTM = (0.9, 0.999, 1e-8)
optmParamsFC = (0.9, 0.999, 1e-8)


EPOCH_NUM = 100
lrt1 = 0.01
lrt2 = 0.05
lrt = lrt1
train_loss = []
val_loss = []
last_loss = -1

look_back = 20
forward_days = 5

def process_data(data, look_back, forward_days, jump=1):
    X,Y = [], []
    for i in range(0, len(data)-look_back-forward_days+1, jump):
        X.append(data[i:(i+look_back)])
        Y.append(data[(i+look_back):(i+look_back+forward_days)])
    return np.array(X),np.array(Y)

dataset = cIMFs
dataset.shape

train_size = 0.8
validation_size = 0.1

train_data = dataset[:int(dataset.shape[0]*train_size), :]
train_price_ = np.array(SZ_index[["Close"]])[:int(dataset.shape[0]*train_size), :]
test_data = dataset[int(dataset.shape[0]*train_size):,:]
test_price_ = np.array(SZ_index[["Close"]])[int(dataset.shape[0]*train_size):,:]


X_test, Y_test = process_data(test_data, look_back, forward_days, forward_days)
# Y_test_price =  process_data(test_price, look_back, forward_days, forward_days)
_, test_price = process_data(test_price_, look_back, forward_days, forward_days)

X_train, Y_train = process_data(train_data[:-int(train_data.shape[0]*validation_size),:], look_back, forward_days, forward_days)
X_validate, Y_validate = process_data(train_data[int(train_data.shape[0]*(1-validation_size)):,:], look_back, forward_days, forward_days)
_, train_price = process_data(train_price_[:-int(train_data.shape[0]*validation_size),:], look_back, forward_days, forward_days)


Y_test = Y_test.reshape(Y_test.shape[0], -1)
Y_train = Y_train.reshape(Y_train.shape[0], -1)
Y_validate = Y_validate.reshape(Y_validate.shape[0], -1)
# train_price = train_price[:-int(train_data.shape[0]*validation_size), :]
train_price = np.ravel(train_price).reshape(-1,1)
test_price = np.ravel(test_price).reshape(-1,1)

print(f"The shape of X_train is {X_train.shape}")
print(f"The shape of Y_train is {Y_train.shape}")
print(f"The shape of X_validate is {X_validate.shape}")
print(f"The shape of Y_validate is {Y_validate.shape}")
print(f"The shape of X_test is {X_test.shape}")
print(f"The shape of Y_test is {Y_test.shape}")
print(f"The shape of train_price is {train_price.shape}")
print(f"The shape of test_price is {test_price.shape}")

BATCH_SIZE = 10
NUM_NEURONS_FirstLayer = 20
NUM_NEURONS_SecondLayer = 60
optmParamsLSTM = (0.9, 0.999, 1e-8)
optmParamsFC = (0.9, 0.999, 1e-8)

optimizers = AdamOptimizer
lstm_layer1 = LSTMLayer("LSTM1", BATCH_SIZE, NUM_NEURONS_FirstLayer, 1, optimizers, optmParamsLSTM, 0.9, np.float32, 1e-4)
lstm_layer2 = LSTMLayer("LSTM2", BATCH_SIZE, NUM_NEURONS_SecondLayer, 1, optimizers, optmParamsLSTM, 0.99, np.float32, 1e-4)
fc_layer = FCLayer("FC", BATCH_SIZE, NUM_NEURONS_SecondLayer*look_back, Y_train.shape[1], Pass, optimizers, optmParamsFC, True, np.float32, 1e-4)
seqLayers = [lstm_layer1, lstm_layer2, fc_layer]
sess = Session(seqLayers, MSE)
train_loss = []
val_loss = []
last_loss = -1


def iterate_minibatches(input, target, batch_size, shuffle=False):
    assert input.shape[0] == target.shape[0]
    if shuffle:
        indices = np.arange(input.shape[0])
        np.random.shuffle(indices)  
    for start_idx in range(0, input.shape[0]-batch_size+1, batch_size):
        if shuffle:
            output = indices[start_idx:start_idx:batch_size]
        else:
            output = slice(start_idx, start_idx+batch_size)
        yield input[output], target[output]

EPOCH_NUM = 100
lrt1 = 0.01
lrt2 = 0.05
lrt = lrt1

iter = 0
for epoch in range(EPOCH_NUM):
    start = time.time()
    for batch in iterate_minibatches(X_train, Y_train, BATCH_SIZE, False):
        x_batch, y_batch = batch 
        # y_batch = y_batch.reshape(len(y_batch), -1)
        acc_, loss_t = sess.train_steps(x_batch, y_batch, lrt)

    if epoch == 0:
        last_loss = loss_t
    else:
        loss_diff = loss_t - last_loss
        if loss_diff > 0:
            lrt = lrt2
        else:
            lrt = lrt1
        last_loss = loss_t

    _, acc_val, loss_val = sess.validation(X_validate, Y_validate)
    train_loss.append(loss_t)
    val_loss.append(loss_val)
    
    s = time.time() - start
    iter += 1
    print(f"epoch {epoch+1}/{EPOCH_NUM}: train_loss={loss_t:.4f}, train_accuracy={acc_:.4f}, val_loss={loss_val:.4f}, val_accuracy={acc_val:.4f}, time: {s:.3f}, lrt: {lrt}")

fig,ax = plt.subplots(figsize=(8,6))

ax.plot(np.arange(len(train_loss)), train_loss, label="train_loss")
ax.plot(np.arange(len(val_loss)), val_loss, label="val_loss")
ax.legend(loc="best")
plt.show()
# plt.savefig(save_path+r"\CEEMDAN_loss_all.png")

# y_hat_train,loss_train,_,_ = sess.inference(X_train, Y_train, val=True)
# y_hat_ = np.reshape(y_hat_train, (y_hat_train.shape[0], -1, dataset.shape[1]))
# y_train_ = np.reshape(Y_train, (Y_train.shape[0], -1, dataset.shape[1]))

# fig,ax = plt.subplots(y_hat_.shape[-1],1,figsize=(18,(y_hat_.shape[-1])*5))
# ax[0].set_title("IMF after neural network", fontsize=30)
# price_pred = 0
# for i in range(y_hat_.shape[-1]):
#     temp = y_hat_[:,:,i]
#     price_pred += temp.reshape(-1,1)
#     for j in range(len(temp)):
#         ax[i].plot([x+j*forward_days for x in range(len(temp[j]))], temp[j].reshape(-1,1), color="red")
#     ax[i].plot(y_train_[:,:,i].reshape(-1,1), color="darkblue")
# price_pred = scl.inverse_transform(price_pred)
# plt.show()



# plt.savefig(save_path+r"\CEEMDAN_IMF.png")
# Out:
# The shape of X_train is (171, 20, 8)
# The shape of Y_train is (171, 40)
# The shape of X_validate is (15, 20, 8)
# The shape of Y_validate is (15, 40)
# The shape of X_test is (44, 20, 8)
# The shape of Y_test is (44, 40)
# The shape of train_price is (855, 1)
# The shape of test_price is (220, 1)
# epoch 1/100: train_loss=0.0013, train_accuracy=0.0013, val_loss=0.0033, val_accuracy=0.0033, time: 0.530, lrt: 0.01
# epoch 2/100: train_loss=0.0014, train_accuracy=0.0014, val_loss=0.0018, val_accuracy=0.0018, time: 0.987, lrt: 0.05
# epoch 3/100: train_loss=0.0045, train_accuracy=0.0045, val_loss=0.0049, val_accuracy=0.0049, time: 1.023, lrt: 0.05
# epoch 4/100: train_loss=0.0025, train_accuracy=0.0025, val_loss=0.0026, val_accuracy=0.0026, time: 0.787, lrt: 0.01
# epoch 5/100: train_loss=0.0034, train_accuracy=0.0034, val_loss=0.0017, val_accuracy=0.0017, time: 0.568, lrt: 0.05
# epoch 6/100: train_loss=0.0031, train_accuracy=0.0031, val_loss=0.0048, val_accuracy=0.0048, time: 0.511, lrt: 0.01
# epoch 7/100: train_loss=0.0044, train_accuracy=0.0044, val_loss=0.0022, val_accuracy=0.0022, time: 0.483, lrt: 0.05
# epoch 8/100: train_loss=0.0028, train_accuracy=0.0028, val_loss=0.0011, val_accuracy=0.0011, time: 0.475, lrt: 0.01
# epoch 9/100: train_loss=0.0013, train_accuracy=0.0013, val_loss=0.0010, val_accuracy=0.0010, time: 0.479, lrt: 0.01
# epoch 10/100: train_loss=0.0011, train_accuracy=0.0011, val_loss=0.0008, val_accuracy=0.0008, time: 0.502, lrt: 0.01
# epoch 11/100: train_loss=0.0008, train_accuracy=0.0008, val_loss=0.0009, val_accuracy=0.0009, time: 0.460, lrt: 0.01
# epoch 12/100: train_loss=0.0007, train_accuracy=0.0007, val_loss=0.0008, val_accuracy=0.0008, time: 0.449, lrt: 0.01
# epoch 13/100: train_loss=0.0006, train_accuracy=0.0006, val_loss=0.0009, val_accuracy=0.0009, time: 0.503, lrt: 0.01
# epoch 14/100: train_loss=0.0005, train_accuracy=0.0005, val_loss=0.0008, val_accuracy=0.0008, time: 0.438, lrt: 0.01
# epoch 15/100: train_loss=0.0005, train_accuracy=0.0005, val_loss=0.0008, val_accuracy=0.0008, time: 0.553, lrt: 0.01
# epoch 16/100: train_loss=0.0005, train_accuracy=0.0005, val_loss=0.0008, val_accuracy=0.0008, time: 0.758, lrt: 0.01
# epoch 17/100: train_loss=0.0004, train_accuracy=0.0004, val_loss=0.0007, val_accuracy=0.0007, time: 0.673, lrt: 0.01
# epoch 18/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0008, val_accuracy=0.0008, time: 0.628, lrt: 0.01
# epoch 19/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0007, val_accuracy=0.0007, time: 0.443, lrt: 0.01
# epoch 20/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0006, val_accuracy=0.0006, time: 0.440, lrt: 0.05
# epoch 21/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0032, val_accuracy=0.0032, time: 0.463, lrt: 0.01
# epoch 22/100: train_loss=0.0010, train_accuracy=0.0010, val_loss=0.0009, val_accuracy=0.0009, time: 0.425, lrt: 0.05
# epoch 23/100: train_loss=0.0010, train_accuracy=0.0010, val_loss=0.0035, val_accuracy=0.0035, time: 0.430, lrt: 0.01
# epoch 24/100: train_loss=0.0006, train_accuracy=0.0006, val_loss=0.0011, val_accuracy=0.0011, time: 0.456, lrt: 0.01
# epoch 25/100: train_loss=0.0007, train_accuracy=0.0007, val_loss=0.0007, val_accuracy=0.0007, time: 0.424, lrt: 0.05
# epoch 26/100: train_loss=0.0005, train_accuracy=0.0005, val_loss=0.0012, val_accuracy=0.0012, time: 0.452, lrt: 0.01
# epoch 27/100: train_loss=0.0004, train_accuracy=0.0004, val_loss=0.0008, val_accuracy=0.0008, time: 0.530, lrt: 0.01
# epoch 28/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0007, val_accuracy=0.0007, time: 0.608, lrt: 0.01
# epoch 29/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.600, lrt: 0.01
# epoch 30/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0007, val_accuracy=0.0007, time: 0.727, lrt: 0.05
# epoch 31/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0013, val_accuracy=0.0013, time: 0.545, lrt: 0.05
# epoch 32/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0015, val_accuracy=0.0015, time: 0.653, lrt: 0.01
# epoch 33/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0008, val_accuracy=0.0008, time: 0.494, lrt: 0.01
# epoch 34/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0006, val_accuracy=0.0006, time: 0.559, lrt: 0.05
# epoch 35/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0019, val_accuracy=0.0019, time: 0.459, lrt: 0.01
# epoch 36/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 1.045, lrt: 0.01
# epoch 37/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.995, lrt: 0.05
# epoch 38/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0007, val_accuracy=0.0007, time: 1.159, lrt: 0.05
# epoch 39/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0013, val_accuracy=0.0013, time: 1.753, lrt: 0.01
# epoch 40/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 0.981, lrt: 0.01
# epoch 41/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.730, lrt: 0.05
# epoch 42/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.665, lrt: 0.01
# epoch 43/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.783, lrt: 0.05
# epoch 44/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.899, lrt: 0.01
# epoch 45/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0007, val_accuracy=0.0007, time: 0.854, lrt: 0.05
# epoch 46/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0009, val_accuracy=0.0009, time: 1.044, lrt: 0.01
# epoch 47/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0008, val_accuracy=0.0008, time: 1.093, lrt: 0.05
# epoch 48/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0009, val_accuracy=0.0009, time: 1.059, lrt: 0.01
# epoch 49/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0006, val_accuracy=0.0006, time: 1.016, lrt: 0.05
# epoch 50/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0011, val_accuracy=0.0011, time: 0.897, lrt: 0.01
# epoch 51/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.876, lrt: 0.01
# epoch 52/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0005, val_accuracy=0.0005, time: 0.872, lrt: 0.05
# epoch 53/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0011, val_accuracy=0.0011, time: 0.971, lrt: 0.05
# epoch 54/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0008, val_accuracy=0.0008, time: 0.908, lrt: 0.01
# epoch 55/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0006, val_accuracy=0.0006, time: 1.084, lrt: 0.05
# epoch 56/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0010, val_accuracy=0.0010, time: 1.100, lrt: 0.05
# epoch 57/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 0.996, lrt: 0.01
# epoch 58/100: train_loss=0.0003, train_accuracy=0.0003, val_loss=0.0007, val_accuracy=0.0007, time: 0.701, lrt: 0.05
# epoch 59/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0008, val_accuracy=0.0008, time: 0.938, lrt: 0.01
# epoch 60/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0006, val_accuracy=0.0006, time: 0.701, lrt: 0.05
# epoch 61/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 1.251, lrt: 0.01
# epoch 62/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.874, lrt: 0.01
# epoch 63/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 2.499, lrt: 0.05
# epoch 64/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0006, val_accuracy=0.0006, time: 0.926, lrt: 0.05
# epoch 65/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0008, val_accuracy=0.0008, time: 0.513, lrt: 0.01
# epoch 66/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.464, lrt: 0.05
# epoch 67/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 0.505, lrt: 0.05
# epoch 68/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.606, lrt: 0.01
# epoch 69/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0007, val_accuracy=0.0007, time: 0.617, lrt: 0.05
# epoch 70/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 1.109, lrt: 0.01
# epoch 71/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.639, lrt: 0.05
# epoch 72/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 0.642, lrt: 0.01
# epoch 73/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.866, lrt: 0.05
# epoch 74/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 1.029, lrt: 0.01
# epoch 75/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.724, lrt: 0.05
# epoch 76/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0008, val_accuracy=0.0008, time: 0.744, lrt: 0.01
# epoch 77/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0005, val_accuracy=0.0005, time: 0.822, lrt: 0.05
# epoch 78/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0008, val_accuracy=0.0008, time: 0.499, lrt: 0.01
# epoch 79/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0006, val_accuracy=0.0006, time: 0.555, lrt: 0.05
# epoch 80/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0007, val_accuracy=0.0007, time: 0.476, lrt: 0.01
# epoch 81/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0005, val_accuracy=0.0005, time: 0.562, lrt: 0.05
# epoch 82/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0009, val_accuracy=0.0009, time: 0.543, lrt: 0.01
# epoch 83/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 1.138, lrt: 0.01
# epoch 84/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0004, val_accuracy=0.0004, time: 0.924, lrt: 0.01
# epoch 85/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 1.147, lrt: 0.01
# epoch 86/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.559, lrt: 0.05
# epoch 87/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.539, lrt: 0.01
# epoch 88/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.545, lrt: 0.05
# epoch 89/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.717, lrt: 0.05
# epoch 90/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.493, lrt: 0.01
# epoch 91/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0006, val_accuracy=0.0006, time: 0.474, lrt: 0.05
# epoch 92/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0009, val_accuracy=0.0009, time: 0.577, lrt: 0.01
# epoch 93/100: train_loss=0.0002, train_accuracy=0.0002, val_loss=0.0005, val_accuracy=0.0005, time: 0.508, lrt: 0.05
# epoch 94/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0008, val_accuracy=0.0008, time: 0.559, lrt: 0.01
# epoch 95/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.800, lrt: 0.01
# epoch 96/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0004, val_accuracy=0.0004, time: 1.069, lrt: 0.01
# epoch 97/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.779, lrt: 0.05
# epoch 98/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.644, lrt: 0.05
# epoch 99/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0004, val_accuracy=0.0004, time: 0.549, lrt: 0.01
# epoch 100/100: train_loss=0.0001, train_accuracy=0.0001, val_loss=0.0005, val_accuracy=0.0005, time: 0.521, lrt: 0.05

# %%
y_hat_train,loss_train,_,_ = sess.inference(X_train, Y_train, val=True)
y_hat_ = np.reshape(y_hat_train, (y_hat_train.shape[0], -1, dataset.shape[1]))
y_train_ = np.reshape(Y_train, (Y_train.shape[0], -1, dataset.shape[1]))

fig,ax = plt.subplots(2,4,figsize=(20,8))
# ax[0].set_title("Intrinsic Mode Functions", fontsize=30)
error = np.ravel(np.array(data_ceemd))
price_pred = 0
for i in range(1):
    for j in range(4):
        temp = y_hat_[:,:,i*4+j]
        price_pred += temp.reshape(-1,1)
        ax[i,j].plot(y_train_[:,:,i*4+j].reshape(-1,1), color="darkblue")
        for k in range(len(temp)):
            ax[i,j].plot([x+k*forward_days for x in range(len(temp[k]))], temp[k].reshape(-1,1), color="red")
        ax[i,j].legend(labels=["predicted IMF%d"%(i*4+j+1)],loc="upper left")

for j in range(4):
    temp = y_hat_[:,:,4+j]
    price_pred += temp.reshape(-1,1)
    ax[1,j].plot(y_train_[:,:,4+j].reshape(-1,1), color="darkblue")
    for k in range(len(temp)):
        ax[1,j].plot([x+k*forward_days for x in range(len(temp[k]))], temp[k].reshape(-1,1), color="red")
    ax[1,j].legend(labels=["predicted IMF%d"%(4+j+1)], loc="upper left")

# %%
price_pred = scl.inverse_transform(price_pred)

fig,ax = plt.subplots(figsize=(8,6))

ax.plot(pd.to_datetime(SS_index.index)[:train_price.shape[0]], np.ravel(train_price), color="darkblue", label="399001.SZ")
ax.plot(pd.to_datetime(SS_index.index)[:train_price.shape[0]], np.ravel(price_pred), color="red", label="Prediction")

ax.legend()

# %%
y_hat_test,loss_test,_,_ = sess.inference(X_test, Y_test, val=True)
y_hat_ = np.reshape(y_hat_test, (y_hat_test.shape[0], -1, dataset.shape[1]))
y_train_ = np.reshape(Y_test, (Y_test.shape[0], -1, dataset.shape[1]))

fig,ax = plt.subplots(2,4,figsize=(20,8))
# ax[0].set_title("Intrinsic Mode Functions", fontsize=30)
error = np.ravel(np.array(data_ceemd))
price_pred = 0
for i in range(1):
    for j in range(4):
        temp = y_hat_[:,:,i*4+j]
        price_pred += temp.reshape(-1,1)
        ax[i,j].plot(y_train_[:,:,i*4+j].reshape(-1,1), color="darkblue")
        for k in range(len(temp)):
            ax[i,j].plot([x+k*forward_days for x in range(len(temp[k]))], temp[k].reshape(-1,1), color="red")
        ax[i,j].legend(labels=["predicted IMF%d"%(i*4+j+1)],loc="upper left")

for j in range(4):
    temp = y_hat_[:,:,4+j]
    price_pred += temp.reshape(-1,1)
    ax[1,j].plot(y_train_[:,:,4+j].reshape(-1,1), color="darkblue")
    for k in range(len(temp)):
        ax[1,j].plot([x+k*forward_days for x in range(len(temp[k]))], temp[k].reshape(-1,1), color="red")
    ax[1,j].legend(labels=["predicted IMF%d"%(4+j+1)], loc="upper left")

# %%
price_pred = scl.inverse_transform(price_pred)

fig,ax = plt.subplots(figsize=(8,6))

ax.plot(pd.to_datetime(SS_index.index)[-test_price.shape[0]:], np.ravel(test_price), color="darkblue", label="000001.SH")
ax.plot(pd.to_datetime(SS_index.index)[-test_price.shape[0]:], np.ravel(price_pred), color="red", label="Prediction")

ax.legend()
